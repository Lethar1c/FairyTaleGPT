# %% [markdown]
# #### Generated by ChatGPT

# %% [markdown]
# # Проект: Mini-GPT на корпусе русских сказок
#
# ## Цель
#
# Разработать и обучить небольшую GPT-подобную языковую модель на реальном текстовом корпусе.
#
# Основной фокус проекта:
#
# * языковое моделирование;
# * подготовка данных;
# * токенизация;
# * обучение;
# * генерация текста;
# * анализ поведения модели;
# * инженерные аспекты LLM.
#
# Реализация базовых компонентов Transformer вручную не является целью проекта.
#
# Допускается использование:
#
# * nn.MultiheadAttention;
# * nn.TransformerDecoderLayer;
# * готовых реализаций GPT-блоков;
# * компонентов PyTorch.
#
# ---
#
# # Часть 1. Сбор и подготовка данных
#
# ## Источник
#
# Собрать корпус русских сказок.
#
# Требования:
#
# * минимум 5 МБ текста;
# * желательно 10–20 МБ;
# * единый стиль;
# * удалены HTML-теги;
# * удалены служебные элементы.
#
# ---
#
# ## Анализ корпуса
#
# Посчитать:
#
# * количество символов;
# * количество слов;
# * количество уникальных символов;
# * количество уникальных слов.
#
# Подготовить краткий отчёт.
#
# ---
#
# # Часть 2. Токенизация
#
# Реализовать и сравнить два подхода.
#
# ## Вариант 1
#
# Символьная токенизация.
#
# ---
#
# ## Вариант 2
#
# Subword-токенизация.
#
# Изучить:
#
# * BPE;
# * SentencePiece.
#
# Использовать готовую библиотеку.
#
# ---
#
# ## Сравнить
#
# Для обоих вариантов:
#
# * размер словаря;
# * среднюю длину последовательности;
# * скорость обучения;
# * качество генерации.
#
# ---
#
# # Часть 3. Dataset
#
# Реализовать задачу:
#
# ```text
# Next Token Prediction
# ```
#
# Пары обучения:
#
# ```python
# x = tokens[i:i+context]
# y = tokens[i+1:i+context+1]
# ```
#
# ---
#
# Исследовать влияние:
#
# ```python
# context_length
# ```
#
# на качество модели.
#
# Проверить:
#
# ```python
# 64
# 128
# 256
# ```
#
# ---
#
# # Часть 4. Модель
#
# Использовать GPT-подобную архитектуру.
#
# Минимальная конфигурация:
#
# ```python
# d_model = 128
#
# num_heads = 4
#
# num_layers = 4
#
# ffn_dim = 512
# ```
#
# ---
#
# Изучить:
#
# * количество параметров;
# * потребление памяти;
# * время обучения.
#
# ---
#
# # Часть 5. Обучение
#
# Использовать:
#
# ```python
# AdamW
# ```
#
# ---
#
# Изучить влияние:
#
# * learning rate;
# * weight decay;
# * batch size.
#
# ---
#
# Логировать:
#
# * train loss;
# * validation loss.
#
# ---
#
# Построить графики обучения.
#
# ---
#
# # Часть 6. Генерация
#
# Реализовать:
#
# ## Greedy Decoding
#
# ---
#
# ## Temperature Sampling
#
# Проверить:
#
# ```python
# 0.5
# 1.0
# 1.5
# ```
#
# ---
#
# ## Top-K Sampling
#
# Проверить:
#
# ```python
# 5
# 10
# 20
# ```
#
# ---
#
# ## Top-P Sampling
#
# Проверить различные значения:
#
# ```python
# 0.8
# 0.9
# 0.95
# ```
#
# ---
#
# # Часть 7. Анализ модели
#
# Исследовать:
#
# * повторения;
# * деградацию текста;
# * влияние длины контекста;
# * влияние токенизации.
#
# ---
#
# Подготовить примеры генерации.
#
# ---
#
# # Часть 8. Исследовательская часть
#
# Выбрать один вопрос.
#
# Например:
#
# ### Эксперимент A
#
# Символьная токенизация против BPE.
#
# ---
#
# ### Эксперимент B
#
# Влияние размера контекста.
#
# ---
#
# ### Эксперимент C
#
# Влияние числа слоёв.
#
# ---
#
# ### Эксперимент D
#
# Влияние размера модели.
#
# ---
#
# Провести абляционное исследование и оформить выводы.
#
# ---
#
# # Финальный результат
#
# Получить модель, которая:
#
# * обучается на реальном корпусе;
# * генерирует осмысленный текст;
# * поддерживает различные стратегии генерации;
# * сопровождается анализом экспериментов.
#
# ---
#
# # Что должно быть освоено после проекта
#
# * языковое моделирование;
# * подготовка текстовых корпусов;
# * токенизация;
# * обучение GPT-моделей;
# * генерация текста;
# * sampling-алгоритмы;
# * анализ качества генерации;
# * постановка и проведение ML-экспериментов.
